# %%
##########################################################
# Linear Algebra Modules
# - Vectors (Addition, Cross Product, Projection,)
# - Matrixes (Transformation, Rotation, Determinant)
# - Eigenvalues and eigenvectors
# - More
##########################################################

##########################################################
# Imports
##########################################################
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
from rlo import *
from section1 import section1
from section2 import section2
from section3 import section3

import warnings
warnings.filterwarnings('ignore')

# %matplotlib notebook
SCORES=np.zeros(3)

# %%
fig = plt.figure()
s1 = section1(SCORES, font_size=3)
s1(fig)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
s2 = section2(SCORES, font_size=3)
s2(fig)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
s3 = section3(SCORES, font_size=3)
s3(fig)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
final_report(SCORES)
# Out:
# In section 1 - [Addition/Cross Product/Projection], your self reported score is 0.0
# In section 2 - [Transformation/Rotation/Determinant], your self reported score is 0.0
# In section 3 - [Eigenvector/Eigenvalue], your self reported score is 0.0
# Your self reported average score on this Linear Algebra review tool is 0.00
